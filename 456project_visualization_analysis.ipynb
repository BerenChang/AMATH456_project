# %% [markdown]
# Package import and data preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_csv('ternary_3hidden_softplus_l1.csv', index_col=[0])
df2 = pd.read_csv('ternary_3hidden_softplus_l2.csv', index_col=[0])
df3 = pd.read_csv('ternary_6hidden_relu_softplus.csv', index_col=[0])

# %% [markdown]
# Sparsity

# %%
scatter = plt.scatter(df1['Sparsity'],df1['Test acc'])
plt.title("Test accuracy vs Sparsity") #title
plt.xlabel("Sparsity(%)") #x label
plt.ylabel("Test Accuracy(%)") #y label
ax = scatter.axes
ax.invert_xaxis()
plt.show()

# %%
Sparsity vs loss

# %%
t = np.arange(0, 100, 1)
data1 = df1['Sparsity']
data2 = df1['Valid loss']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('epoch(s)')
ax1.set_ylabel('Sparsity(%)', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Validation loss', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

#plt.axvline(x=77, color = 'brown')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %% [markdown]
# Sparsity vs accuracy

# %%
t = np.arange(0, 100, 1)
data1 = df1['Sparsity']
data2 = df1['Test acc']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('epoch(s)')
ax1.set_ylabel('Sparsity(%)', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Test Accuracy(%)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.axvline(x=np.argmax(df['Test acc']), color = 'brown')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
# Plot
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 100, 1)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10,3))
ax1.semilogy(t, df1['Train loss'], '-o', label='Train loss')
ax1.semilogy(t, df1['Valid loss'], '-o', label='Valid loss')
ax1.semilogy(t, df1['Test loss'], '-o', label='Test loss')

ax2.plot(t, df1['Train acc'], '-o', label='Train acc')
ax2.plot(t, df1['Valid acc'], '-o', label='Valid acc')
ax2.plot(t, df1['Test acc'], '-o', label='Test acc')

ax3.plot(t, df1['Sparsity'], '-o', label='Sparsity')

for ax in [ax1,ax2,ax3]:
    ax.legend()

ax2.set_ylim(0.8,1)
    
#print('Final results: ', losses_and_accs[-1])
# Out:
# (0.8, 1.0)

# %% [markdown]
# L1 and L2

# %%
t = np.arange(0, 100, 1)
data1 = df1['Test acc']
data2 = df2['Test acc']
data3 = df3['Sparsity']

plt.plot(t, data1, label = "Model using L1")
plt.plot(t, data2, label = "Model using L2")
#plt.plot(t, data3, label = "Test loss of six layer model")
plt.xlabel('epoch(s)')
plt.ylabel('Test Accuracy(%)')
plt.legend()
plt.show()
